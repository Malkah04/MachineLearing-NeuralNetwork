# %%
import numpy as np

# %%
def sigmoid(x):
    return 1 / 1 + np.exp(-x)

def diffSigmoid(x):
    return x * (1-x)

input = [ [a,b] for a in range(2) for b in range(2) ]
input =np.array(input)

output= np.array([1,0,0,1])

w1 = np.zeros(4)
b = 0

print(output)
# Out:
# [1 0 0 1]

# %%
def train(epoch):
    for i in range(epoch):
        hidden_input = w1 @ input +b
        hidden_output = sigmoid(hidden_input)
